# %% [markdown]
# ## Data Preprocessing
#
# The purpose of this notebook is to preprocess the datasets, i.e.
# * create subsets with data of interest,
# * deal with missing values,
# * combine both datasets,
# * create datasets to be used for statistical analyses and modelling.
#
# The datasets to be analyzed are
# * the Happy Planet Index for 2016 (see https://happyplanetindex.org/),
# * the World Development Indicators (1960 - 2019) by the World Bank (see https://datacatalog.worldbank.org/dataset/world-development-indicators)

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import WDI data (World Development Indicators)
df_wdi = pd.read_csv('../data/raw_data/WDIData.csv')

# %%
# Import HPI dataset (Happy Planet Index)
df_hpi = pd.read_excel('../data/raw_data/hpi-data-2016.xlsx', sheet_name = 'Complete HPI data', header = 5, usecols = 'B:O')

# %%
# Create DataFrame with WDI data for one year
# (in this case 2016, to be congruent with the HPI data)
year = '2016'
custom_list = [[df_wdi['Indicator Code'][row],df_wdi['Country Name'][row],df_wdi[year][row]] for row in range(len(df_wdi))]

df_columns = ['Indicator Code', 'Country Name', year]
custom_wdi_df = pd.DataFrame(custom_list, columns = df_columns)

# %%
print(custom_wdi_df.head())
print('\nShape:',custom_wdi_df.shape)
# Out:
#       Indicator Code Country Name       2016
# 0      PA.NUS.PPP.05   Arab World        NaN
# 1  PA.NUS.PRVT.PP.05   Arab World        NaN
# 2     EG.CFT.ACCS.ZS   Arab World  84.510171
# 3     EG.ELC.ACCS.ZS   Arab World  89.678685
# 4  EG.ELC.ACCS.RU.ZS   Arab World  79.665635
#
# Shape: (377256, 3)

# %%
# Add Happy Planet Index value per Country from the HPI dataset

# Prepare HPI DataFrame for concatenation
# Include only relevant columns
df_hpi_mod = df_hpi[['Country', 'Happy Planet Index']]

# Include only relevant rows
df_hpi_mod = df_hpi_mod.iloc[:140]    

#df_hpi_mod

# %%
# Find out which Country Names in both datasets match
custom_wdi_df_match = custom_wdi_df.merge(df_hpi_mod, left_on='Country Name', right_on='Country', how='inner', suffixes=('WDI ','HPI '))
matching_countries_num = custom_wdi_df_match['Country Name'].unique().shape[0]
matching_countries_num
# Out:
# 125

# %%
# Find out which Country Names in both datasets do not match
custom_wdi_df_all = custom_wdi_df.merge(df_hpi_mod, left_on='Country Name', right_on='Country', how='outer', suffixes=('WDI ','HPI '))
non_matching_countries_wdi = custom_wdi_df_all['Country Name'][custom_wdi_df_all['Country Name'] != custom_wdi_df_all['Country']]
non_matching_countries_wdi = non_matching_countries_wdi[non_matching_countries_wdi.isnull() == False].unique()
print('WDI not matching countries:',non_matching_countries_wdi.shape[0])

non_matching_countries_hpi = custom_wdi_df_all['Country'][custom_wdi_df_all['Country'] != custom_wdi_df_all['Country Name']]
non_matching_countries_hpi = non_matching_countries_hpi[non_matching_countries_hpi.isnull() == False].unique()
print('HPI not matching countries:',non_matching_countries_hpi.shape[0])

print(non_matching_countries_wdi)
print(non_matching_countries_hpi)
# Out:
# WDI not matching countries: 139
# HPI not matching countries: 15
# ['Arab World' 'Caribbean small states' 'Central Europe and the Baltics'
#  'Early-demographic dividend' 'East Asia & Pacific'
#  'East Asia & Pacific (excluding high income)'
#  'East Asia & Pacific (IDA & IBRD countries)' 'Euro area'
#  'Europe & Central Asia' 'Europe & Central Asia (excluding high income)'
#  'Europe & Central Asia (IDA & IBRD countries)' 'European Union'
#  'Fragile and conflict affected situations'
#  'Heavily indebted poor countries (HIPC)' 'High income' 'IBRD only'
#  'IDA & IBRD total' 'IDA blend' 'IDA only' 'IDA total'
#  'Late-demographic dividend' 'Latin America & Caribbean'
#  'Latin America & Caribbean (excluding high income)'
#  'Latin America & the Caribbean (IDA & IBRD countries)'
#  'Least developed countries: UN classification' 'Low & middle income'
#  'Low income' 'Lower middle income' 'Middle East & North Africa'
#  'Middle East & North Africa (excluding high income)'
#  'Middle East & North Africa (IDA & IBRD countries)' 'Middle income'
#  'North America' 'Not classified' 'OECD members' 'Other small states'
#  'Pacific island small states' 'Post-demographic dividend'
#  'Pre-demographic dividend' 'Small states' 'South Asia'
#  'South Asia (IDA & IBRD)' 'Sub-Saharan Africa'
#  'Sub-Saharan Africa (excluding high income)'
#  'Sub-Saharan Africa (IDA & IBRD countries)' 'Upper middle income' 'World'
#  'American Samoa' 'Andorra' 'Angola' 'Antigua and Barbuda' 'Aruba'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Barbados' 'Bermuda'
#  'British Virgin Islands' 'Brunei Darussalam' 'Cabo Verde'
#  'Cayman Islands' 'Central African Republic' 'Channel Islands'
#  'Congo, Dem. Rep.' 'Congo, Rep.' 'Cuba' 'Curacao' 'Dominica'
#  'Egypt, Arab Rep.' 'Equatorial Guinea' 'Eritrea' 'Eswatini'
#  'Faroe Islands' 'Fiji' 'French Polynesia' 'Gambia, The' 'Gibraltar'
#  'Greenland' 'Grenada' 'Guam' 'Guinea-Bissau' 'Guyana'
#  'Hong Kong SAR, China' 'Iran, Islamic Rep.' 'Isle of Man' 'Jordan'
#  'Kiribati' 'Korea, Dem. People’s Rep.' 'Korea, Rep.' 'Kosovo' 'Kuwait'
#  'Kyrgyz Republic' 'Lao PDR' 'Libya' 'Liechtenstein' 'Macao SAR, China'
#  'Madagascar' 'Maldives' 'Mali' 'Marshall Islands' 'Micronesia, Fed. Sts.'
#  'Moldova' 'Monaco' 'Nauru' 'New Caledonia' 'North Macedonia'
#  'Northern Mariana Islands' 'Palau' 'Papua New Guinea' 'Puerto Rico'
#  'Qatar' 'Russian Federation' 'Samoa' 'San Marino' 'Sao Tome and Principe'
#  'Saudi Arabia' 'Seychelles' 'Singapore' 'Sint Maarten (Dutch part)'
#  'Slovak Republic' 'Solomon Islands' 'Somalia' 'South Sudan'
#  'St. Kitts and Nevis' 'St. Lucia' 'St. Martin (French part)'
#  'St. Vincent and the Grenadines' 'Sudan' 'Syrian Arab Republic'
#  'Timor-Leste' 'Tonga' 'Turks and Caicos Islands' 'Tuvalu'
#  'United Arab Emirates' 'United States' 'Venezuela, RB'
#  'Virgin Islands (U.S.)' 'West Bank and Gaza' 'Yemen, Rep.']
# ['Egypt' 'Hong Kong' 'Iran' 'Kyrgyzstan' 'Macedonia' 'Palestine'
#  'Republic of Congo' 'Russia' 'Slovakia' 'South Korea' 'Swaziland' 'Syria'
#  'United States of America' 'Venezuela' 'Yemen']

# %%
# Manually create a matching table of non-matching country names
non_matching_countries_hpi
wdi_pair_list = ['Egypt, Arab Rep.',
                 'Hong Kong SAR, China',
                 'Iran, Islamic Rep.',
                 'Kyrgyz Republic',
                 'North Macedonia',
                 'Palestine',   # no match found in WDI
                 'Congo, Rep.',
                 'Russian Federation',
                 'Slovak Republic',
                 'Korea, Rep.',
                 'Eswatini',
                 'Syrian Arab Republic',
                 'United States',
                 'Venezuela, RB',
                 'Yemen, Rep.'
                ]
wdi_pair_list
# Out:
# ['Egypt, Arab Rep.',
#  'Hong Kong SAR, China',
#  'Iran, Islamic Rep.',
#  'Kyrgyz Republic',
#  'North Macedonia',
#  'Palestine',
#  'Congo, Rep.',
#  'Russian Federation',
#  'Slovak Republic',
#  'Korea, Rep.',
#  'Eswatini',
#  'Syrian Arab Republic',
#  'United States',
#  'Venezuela, RB',
#  'Yemen, Rep.']

# %%
# Transform Indicator rows into Indicator columns
custom_wdi_df_indcols = custom_wdi_df.pivot(index = 'Country Name', columns = 'Indicator Code', values = '2016')
custom_wdi_df_indcols = custom_wdi_df_indcols.rename_axis(None, axis=1).reset_index()
custom_wdi_df_indcols.head()
# Out:
#      Country Name  AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  AG.CON.FERT.ZS  \
# 0     Afghanistan             NaN         590.067055       12.182300
# 1         Albania             NaN                NaN      126.138483
# 2         Algeria             NaN           8.209376       22.315273
# 3  American Samoa             NaN                NaN             NaN
# 4         Andorra             NaN                NaN             NaN
#
#    AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.HA  AG.LND.ARBL.HA.PC  \
# 0   379100.000000       58.067580    7.729000e+06           0.218437
# 1    11816.999512       43.127735    6.203000e+05           0.215674
# 2   413601.992188       17.365539    7.404200e+06           0.182588
# 3       49.000001       24.500000    3.000000e+03           0.053820
# 4      187.800007       39.957448    7.800000e+02           0.010091
#
#    AG.LND.ARBL.ZS  AG.LND.CREL.HA           ...             \
# 0       11.838679       2793133.0           ...
# 1       22.638686        148084.0           ...
# 2        3.108736       3376331.0           ...
# 3       15.000000             NaN           ...
# 4        1.659574             NaN           ...
#
#    per_sa_allsa.cov_q4_tot  per_sa_allsa.cov_q5_tot  per_si_allsi.adq_pop_tot  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
#
#    per_si_allsi.ben_q1_tot  per_si_allsi.cov_pop_tot  per_si_allsi.cov_q1_tot  \
# 0                      NaN                       NaN                      NaN
# 1                      NaN                       NaN                      NaN
# 2                      NaN                       NaN                      NaN
# 3                      NaN                       NaN                      NaN
# 4                      NaN                       NaN                      NaN
#
#    per_si_allsi.cov_q2_tot  per_si_allsi.cov_q3_tot  per_si_allsi.cov_q4_tot  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    per_si_allsi.cov_q5_tot
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 1430 columns]

# %%
# Replace non-matching country names before
df_hpi_mod2 = df_hpi_mod.replace(non_matching_countries_hpi,wdi_pair_list)

# %%
# Merge DataFrames
custom_wdi_df_match2 = custom_wdi_df_indcols.merge(df_hpi_mod2, left_on='Country Name', right_on='Country', how='inner')
matching_countries_num2 = custom_wdi_df_match2['Country Name'].unique().shape[0]
matching_countries_num2
# Out:
# 139

# %%
# Remove columns with only missing data and duplicated Country column
nan_columns = set(custom_wdi_df_match2.columns[custom_wdi_df_match2.isnull().mean() == 1])
nan_columns

wdi_hpi_2016_df = custom_wdi_df_match2.drop(nan_columns, axis = 1)
wdi_hpi_2016_df = wdi_hpi_2016_df.drop('Country', axis = 1)

# %%
# Show columns without missing data
columns_no_nulls = set(wdi_hpi_2016_df.columns[wdi_hpi_2016_df.isnull().mean()==0])
columns_no_nulls
# Out:
# {'AG.LND.AGRI.K2',
#  'AG.LND.AGRI.ZS',
#  'AG.LND.ARBL.HA',
#  'AG.LND.ARBL.HA.PC',
#  'AG.LND.ARBL.ZS',
#  'AG.LND.TOTL.K2',
#  'AG.PRD.CREL.MT',
#  'AG.PRD.CROP.XD',
#  'AG.PRD.FOOD.XD',
#  'AG.PRD.LVSK.XD',
#  'AG.SRF.TOTL.K2',
#  'Country Name',
#  'EG.ELC.ACCS.RU.ZS',
#  'EG.ELC.ACCS.UR.ZS',
#  'EG.ELC.ACCS.ZS',
#  'EN.POP.DNST',
#  'ER.FSH.CAPT.MT',
#  'ER.FSH.PROD.MT',
#  'ER.LND.PTLD.ZS',
#  'ER.PTD.TOTL.ZS',
#  'Happy Planet Index',
#  'IT.CEL.SETS',
#  'IT.CEL.SETS.P2',
#  'IT.MLT.MAIN',
#  'IT.MLT.MAIN.P2',
#  'IT.NET.SECR',
#  'IT.NET.SECR.P6',
#  'IT.NET.USER.ZS',
#  'NY.ADJ.DMIN.CD',
#  'NY.ADJ.DNGY.CD',
#  'SH.H2O.BASW.ZS',
#  'SH.STA.BASS.ZS',
#  'SH.TBS.DTEC.ZS',
#  'SH.TBS.INCD',
#  'SL.AGR.EMPL.FE.ZS',
#  'SL.AGR.EMPL.MA.ZS',
#  'SL.AGR.EMPL.ZS',
#  'SL.EMP.1524.SP.FE.ZS',
#  'SL.EMP.1524.SP.MA.ZS',
#  'SL.EMP.1524.SP.ZS',
#  'SL.EMP.MPYR.FE.ZS',
#  'SL.EMP.MPYR.MA.ZS',
#  'SL.EMP.MPYR.ZS',
#  'SL.EMP.SELF.FE.ZS',
#  'SL.EMP.SELF.MA.ZS',
#  'SL.EMP.SELF.ZS',
#  'SL.EMP.TOTL.SP.FE.ZS',
#  'SL.EMP.TOTL.SP.MA.ZS',
#  'SL.EMP.TOTL.SP.ZS',
#  'SL.EMP.VULN.FE.ZS',
#  'SL.EMP.VULN.MA.ZS',
#  'SL.EMP.VULN.ZS',
#  'SL.EMP.WORK.FE.ZS',
#  'SL.EMP.WORK.MA.ZS',
#  'SL.EMP.WORK.ZS',
#  'SL.FAM.WORK.FE.ZS',
#  'SL.FAM.WORK.MA.ZS',
#  'SL.FAM.WORK.ZS',
#  'SL.GDP.PCAP.EM.KD',
#  'SL.IND.EMPL.FE.ZS',
#  'SL.IND.EMPL.MA.ZS',
#  'SL.IND.EMPL.ZS',
#  'SL.SRV.EMPL.FE.ZS',
#  'SL.SRV.EMPL.MA.ZS',
#  'SL.SRV.EMPL.ZS',
#  'SL.TLF.ACTI.1524.FE.ZS',
#  'SL.TLF.ACTI.1524.MA.ZS',
#  'SL.TLF.ACTI.1524.ZS',
#  'SL.TLF.ACTI.FE.ZS',
#  'SL.TLF.ACTI.MA.ZS',
#  'SL.TLF.ACTI.ZS',
#  'SL.TLF.CACT.FE.ZS',
#  'SL.TLF.CACT.FM.ZS',
#  'SL.TLF.CACT.MA.ZS',
#  'SL.TLF.CACT.ZS',
#  'SL.TLF.TOTL.FE.ZS',
#  'SL.TLF.TOTL.IN',
#  'SL.UEM.1524.FE.ZS',
#  'SL.UEM.1524.MA.ZS',
#  'SL.UEM.1524.ZS',
#  'SL.UEM.TOTL.FE.ZS',
#  'SL.UEM.TOTL.MA.ZS',
#  'SL.UEM.TOTL.ZS',
#  'SP.ADO.TFRT',
#  'SP.DYN.CBRT.IN',
#  'SP.DYN.CDRT.IN',
#  'SP.DYN.LE00.FE.IN',
#  'SP.DYN.LE00.IN',
#  'SP.DYN.LE00.MA.IN',
#  'SP.DYN.TFRT.IN',
#  'SP.DYN.TO65.FE.ZS',
#  'SP.DYN.TO65.MA.ZS',
#  'SP.POP.0004.FE.5Y',
#  'SP.POP.0004.MA.5Y',
#  'SP.POP.0014.FE.IN',
#  'SP.POP.0014.FE.ZS',
#  'SP.POP.0014.MA.IN',
#  'SP.POP.0014.MA.ZS',
#  'SP.POP.0014.TO',
#  'SP.POP.0014.TO.ZS',
#  'SP.POP.0509.FE.5Y',
#  'SP.POP.0509.MA.5Y',
#  'SP.POP.1014.FE.5Y',
#  'SP.POP.1014.MA.5Y',
#  'SP.POP.1519.FE.5Y',
#  'SP.POP.1519.MA.5Y',
#  'SP.POP.1564.FE.IN',
#  'SP.POP.1564.FE.ZS',
#  'SP.POP.1564.MA.IN',
#  'SP.POP.1564.MA.ZS',
#  'SP.POP.1564.TO',
#  'SP.POP.1564.TO.ZS',
#  'SP.POP.2024.FE.5Y',
#  'SP.POP.2024.MA.5Y',
#  'SP.POP.2529.FE.5Y',
#  'SP.POP.2529.MA.5Y',
#  'SP.POP.3034.FE.5Y',
#  'SP.POP.3034.MA.5Y',
#  'SP.POP.3539.FE.5Y',
#  'SP.POP.3539.MA.5Y',
#  'SP.POP.4044.FE.5Y',
#  'SP.POP.4044.MA.5Y',
#  'SP.POP.4549.FE.5Y',
#  'SP.POP.4549.MA.5Y',
#  'SP.POP.5054.FE.5Y',
#  'SP.POP.5054.MA.5Y',
#  'SP.POP.5559.FE.5Y',
#  'SP.POP.5559.MA.5Y',
#  'SP.POP.6064.FE.5Y',
#  'SP.POP.6064.MA.5Y',
#  'SP.POP.6569.FE.5Y',
#  'SP.POP.6569.MA.5Y',
#  'SP.POP.65UP.FE.IN',
#  'SP.POP.65UP.FE.ZS',
#  'SP.POP.65UP.MA.IN',
#  'SP.POP.65UP.MA.ZS',
#  'SP.POP.65UP.TO',
#  'SP.POP.65UP.TO.ZS',
#  'SP.POP.7074.FE.5Y',
#  'SP.POP.7074.MA.5Y',
#  'SP.POP.7579.FE.5Y',
#  'SP.POP.7579.MA.5Y',
#  'SP.POP.80UP.FE.5Y',
#  'SP.POP.80UP.MA.5Y',
#  'SP.POP.BRTH.MF',
#  'SP.POP.DPND',
#  'SP.POP.DPND.OL',
#  'SP.POP.DPND.YG',
#  'SP.POP.GROW',
#  'SP.POP.TOTL',
#  'SP.POP.TOTL.FE.IN',
#  'SP.POP.TOTL.FE.ZS',
#  'SP.POP.TOTL.MA.IN',
#  'SP.POP.TOTL.MA.ZS',
#  'SP.RUR.TOTL',
#  'SP.RUR.TOTL.ZS',
#  'SP.URB.GROW',
#  'SP.URB.TOTL',
#  'SP.URB.TOTL.IN.ZS',
#  'TM.VAL.MRCH.CD.WT',
#  'TM.VAL.MRCH.HI.ZS',
#  'TM.VAL.MRCH.OR.ZS',
#  'TM.VAL.MRCH.R1.ZS',
#  'TM.VAL.MRCH.R2.ZS',
#  'TM.VAL.MRCH.R3.ZS',
#  'TM.VAL.MRCH.R5.ZS',
#  'TM.VAL.MRCH.RS.ZS',
#  'TM.VAL.MRCH.WL.CD',
#  'TX.VAL.MRCH.CD.WT',
#  'TX.VAL.MRCH.HI.ZS',
#  'TX.VAL.MRCH.OR.ZS',
#  'TX.VAL.MRCH.R1.ZS',
#  'TX.VAL.MRCH.R5.ZS',
#  'TX.VAL.MRCH.RS.ZS',
#  'TX.VAL.MRCH.WL.CD'}

# %%
# Evaluate columns with most missing data
columns_90_nulls = set(wdi_hpi_2016_df.columns[wdi_hpi_2016_df.isnull().mean() > 0.90])
columns_75_nulls = set(wdi_hpi_2016_df.columns[wdi_hpi_2016_df.isnull().mean() > 0.75])    # more than 75% of data is missing
columns_50_nulls = set(wdi_hpi_2016_df.columns[wdi_hpi_2016_df.isnull().mean() > 0.50])

print(len(columns_90_nulls))
print(len(columns_75_nulls))
print(len(columns_50_nulls))
print(wdi_hpi_2016_df.shape[1])
# Out:
# 99
# 192
# 330
# 1274

# %%
# Remove columns with more than 50% of missing data
wdi_hpi_2016_df = wdi_hpi_2016_df.drop(wdi_hpi_2016_df.columns[wdi_hpi_2016_df.isnull().mean() > 0.50], axis = 1)
print(wdi_hpi_2016_df.shape)
# Out:
# (139, 944)

# %%
# Show remaining columns in order to choose columns for the model
col_descr = pd.DataFrame(wdi_hpi_2016_df.columns, columns = ['Indicator Code'])

df_wdi_inds = pd.read_csv('../data/raw_data/WDISeries.csv')

col_descr = col_descr.merge(df_wdi_inds, left_on='Indicator Code', right_on='Series Code', how='left')
col_descr
# Out:
#          Indicator Code        Series Code  \
# 0          Country Name                NaN
# 1        AG.CON.FERT.ZS     AG.CON.FERT.ZS
# 2        AG.LND.AGRI.K2     AG.LND.AGRI.K2
# 3        AG.LND.AGRI.ZS     AG.LND.AGRI.ZS
# 4        AG.LND.ARBL.HA     AG.LND.ARBL.HA
# 5     AG.LND.ARBL.HA.PC  AG.LND.ARBL.HA.PC
# 6        AG.LND.ARBL.ZS     AG.LND.ARBL.ZS
# 7        AG.LND.CREL.HA     AG.LND.CREL.HA
# 8        AG.LND.CROP.ZS     AG.LND.CROP.ZS
# 9        AG.LND.FRST.K2     AG.LND.FRST.K2
# 10       AG.LND.FRST.ZS     AG.LND.FRST.ZS
# 11       AG.LND.TOTL.K2     AG.LND.TOTL.K2
# 12       AG.PRD.CREL.MT     AG.PRD.CREL.MT
# 13       AG.PRD.CROP.XD     AG.PRD.CROP.XD
# 14       AG.PRD.FOOD.XD     AG.PRD.FOOD.XD
# 15       AG.PRD.LVSK.XD     AG.PRD.LVSK.XD
# 16       AG.SRF.TOTL.K2     AG.SRF.TOTL.K2
# 17       AG.YLD.CREL.KG     AG.YLD.CREL.KG
# 18    BG.GSR.NFSV.GD.ZS  BG.GSR.NFSV.GD.ZS
# 19       BM.GSR.CMCP.ZS     BM.GSR.CMCP.ZS
# 20       BM.GSR.FCTY.CD     BM.GSR.FCTY.CD
# 21       BM.GSR.GNFS.CD     BM.GSR.GNFS.CD
# 22       BM.GSR.INSF.ZS     BM.GSR.INSF.ZS
# 23       BM.GSR.MRCH.CD     BM.GSR.MRCH.CD
# 24       BM.GSR.NFSV.CD     BM.GSR.NFSV.CD
# 25       BM.GSR.ROYL.CD     BM.GSR.ROYL.CD
# 26       BM.GSR.TOTL.CD     BM.GSR.TOTL.CD
# 27       BM.GSR.TRAN.ZS     BM.GSR.TRAN.ZS
# 28       BM.GSR.TRVL.ZS     BM.GSR.TRVL.ZS
# 29    BM.KLT.DINV.CD.WD  BM.KLT.DINV.CD.WD
# ..                  ...                ...
# 914   TX.VAL.AGRI.ZS.UN  TX.VAL.AGRI.ZS.UN
# 915   TX.VAL.FOOD.ZS.UN  TX.VAL.FOOD.ZS.UN
# 916   TX.VAL.FUEL.ZS.UN  TX.VAL.FUEL.ZS.UN
# 917   TX.VAL.ICTG.ZS.UN  TX.VAL.ICTG.ZS.UN
# 918   TX.VAL.INSF.ZS.WT  TX.VAL.INSF.ZS.WT
# 919   TX.VAL.MANF.ZS.UN  TX.VAL.MANF.ZS.UN
# 920   TX.VAL.MMTL.ZS.UN  TX.VAL.MMTL.ZS.UN
# 921   TX.VAL.MRCH.AL.ZS  TX.VAL.MRCH.AL.ZS
# 922   TX.VAL.MRCH.CD.WT  TX.VAL.MRCH.CD.WT
# 923   TX.VAL.MRCH.HI.ZS  TX.VAL.MRCH.HI.ZS
# 924   TX.VAL.MRCH.OR.ZS  TX.VAL.MRCH.OR.ZS
# 925   TX.VAL.MRCH.R1.ZS  TX.VAL.MRCH.R1.ZS
# 926   TX.VAL.MRCH.R2.ZS  TX.VAL.MRCH.R2.ZS
# 927   TX.VAL.MRCH.R3.ZS  TX.VAL.MRCH.R3.ZS
# 928   TX.VAL.MRCH.R4.ZS  TX.VAL.MRCH.R4.ZS
# 929   TX.VAL.MRCH.R5.ZS  TX.VAL.MRCH.R5.ZS
# 930   TX.VAL.MRCH.R6.ZS  TX.VAL.MRCH.R6.ZS
# 931   TX.VAL.MRCH.RS.ZS  TX.VAL.MRCH.RS.ZS
# 932   TX.VAL.MRCH.WL.CD  TX.VAL.MRCH.WL.CD
# 933   TX.VAL.MRCH.WR.ZS  TX.VAL.MRCH.WR.ZS
# 934   TX.VAL.MRCH.XD.WD  TX.VAL.MRCH.XD.WD
# 935   TX.VAL.OTHR.ZS.WT  TX.VAL.OTHR.ZS.WT
# 936   TX.VAL.SERV.CD.WT  TX.VAL.SERV.CD.WT
# 937      TX.VAL.TECH.CD     TX.VAL.TECH.CD
# 938   TX.VAL.TECH.MF.ZS  TX.VAL.TECH.MF.ZS
# 939   TX.VAL.TRAN.ZS.WT  TX.VAL.TRAN.ZS.WT
# 940   TX.VAL.TRVL.ZS.WT  TX.VAL.TRVL.ZS.WT
# 941         VC.IDP.NWDS        VC.IDP.NWDS
# 942      VC.IHR.PSRC.P5     VC.IHR.PSRC.P5
# 943  Happy Planet Index                NaN
#
#                                                  Topic  \
# 0                                                  NaN
# 1                 Environment: Agricultural production
# 2                                Environment: Land use
# 3                                Environment: Land use
# 4                                Environment: Land use
# 5                                Environment: Land use
# 6                                Environment: Land use
# 7                 Environment: Agricultural production
# 8                                Environment: Land use
# 9                                Environment: Land use
# 10                               Environment: Land use
# 11                               Environment: Land use
# 12                Environment: Agricultural production
# 13                Environment: Agricultural production
# 14                Environment: Agricultural production
# 15                Environment: Agricultural production
# 16                               Environment: Land use
# 17                Environment: Agricultural production
# 18   Economic Policy & Debt: Balance of payments: C...
# 19   Economic Policy & Debt: Balance of payments: C...
# 20   Economic Policy & Debt: Balance of payments: C...
# 21   Economic Policy & Debt: Balance of payments: C...
# 22   Economic Policy & Debt: Balance of payments: C...
# 23   Economic Policy & Debt: Balance of payments: C...
# 24   Economic Policy & Debt: Balance of payments: C...
# 25   Economic Policy & Debt: Balance of payments: C...
# 26   Economic Policy & Debt: Balance of payments: C...
# 27   Economic Policy & Debt: Balance of payments: C...
# 28   Economic Policy & Debt: Balance of payments: C...
# 29   Economic Policy & Debt: Balance of payments: C...
# ..                                                 ...
# 914                    Private Sector & Trade: Exports
# 915                    Private Sector & Trade: Exports
# 916                    Private Sector & Trade: Exports
# 917                     Infrastructure: Communications
# 918                    Private Sector & Trade: Exports
# 919                    Private Sector & Trade: Exports
# 920                    Private Sector & Trade: Exports
# 921                    Private Sector & Trade: Exports
# 922                    Private Sector & Trade: Exports
# 923                    Private Sector & Trade: Exports
# 924                    Private Sector & Trade: Exports
# 925                    Private Sector & Trade: Exports
# 926                    Private Sector & Trade: Exports
# 927                    Private Sector & Trade: Exports
# 928                    Private Sector & Trade: Exports
# 929                    Private Sector & Trade: Exports
# 930                    Private Sector & Trade: Exports
# 931                    Private Sector & Trade: Exports
# 932                    Private Sector & Trade: Exports
# 933                    Private Sector & Trade: Exports
# 934              Private Sector & Trade: Trade indexes
# 935                    Private Sector & Trade: Exports
# 936                    Private Sector & Trade: Exports
# 937                         Infrastructure: Technology
# 938                         Infrastructure: Technology
# 939                    Private Sector & Trade: Exports
# 940                    Private Sector & Trade: Exports
# 941                Public Sector: Conflict & fragility
# 942                Public Sector: Conflict & fragility
# 943                                                NaN
#
#                                         Indicator Name  \
# 0                                                  NaN
# 1    Fertilizer consumption (kilograms per hectare ...
# 2                           Agricultural land (sq. km)
# 3                   Agricultural land (% of land area)
# 4                               Arable land (hectares)
# 5                    Arable land (hectares per person)
# 6                         Arable land (% of land area)
# 7              Land under cereal production (hectares)
# 8                  Permanent cropland (% of land area)
# 9                                 Forest area (sq. km)
# 10                        Forest area (% of land area)
# 11                                  Land area (sq. km)
# 12                     Cereal production (metric tons)
# 13             Crop production index (2004-2006 = 100)
# 14             Food production index (2004-2006 = 100)
# 15        Livestock production index (2004-2006 = 100)
# 16                               Surface area (sq. km)
# 17                       Cereal yield (kg per hectare)
# 18                        Trade in services (% of GDP)
# 19   Communications, computer, etc. (% of service i...
# 20          Primary income payments (BoP, current US$)
# 21    Imports of goods and services (BoP, current US$)
# 22   Insurance and financial services (% of service...
# 23                    Goods imports (BoP, current US$)
# 24                  Service imports (BoP, current US$)
# 25   Charges for the use of intellectual property, ...
# 26   Imports of goods, services and primary income ...
# 27      Transport services (% of service imports, BoP)
# 28         Travel services (% of service imports, BoP)
# 29   Foreign direct investment, net outflows (BoP, ...
# ..                                                 ...
# 914  Agricultural raw materials exports (% of merch...
# 915            Food exports (% of merchandise exports)
# 916            Fuel exports (% of merchandise exports)
# 917       ICT goods exports (% of total goods exports)
# 918  Insurance and financial services (% of commerc...
# 919    Manufactures exports (% of merchandise exports)
# 920  Ores and metals exports (% of merchandise expo...
# 921  Merchandise exports to economies in the Arab W...
# 922                  Merchandise exports (current US$)
# 923  Merchandise exports to high-income economies (...
# 924  Merchandise exports to low- and middle-income ...
# 925  Merchandise exports to low- and middle-income ...
# 926  Merchandise exports to low- and middle-income ...
# 927  Merchandise exports to low- and middle-income ...
# 928  Merchandise exports to low- and middle-income ...
# 929  Merchandise exports to low- and middle-income ...
# 930  Merchandise exports to low- and middle-income ...
# 931  Merchandise exports by the reporting economy, ...
# 932  Merchandise exports by the reporting economy (...
# 933  Merchandise exports to low- and middle-income ...
# 934                    Export value index (2000 = 100)
# 935  Computer, communications and other services (%...
# 936           Commercial service exports (current US$)
# 937              High-technology exports (current US$)
# 938  High-technology exports (% of manufactured exp...
# 939  Transport services (% of commercial service ex...
# 940  Travel services (% of commercial service exports)
# 941  Internally displaced persons, new displacement...
# 942         Intentional homicides (per 100,000 people)
# 943                                                NaN
#
#                                       Short definition  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17   Cereal yield, measured as kilograms per hectar...
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 914                                                NaN
# 915                                                NaN
# 916                                                NaN
# 917                                                NaN
# 918                                                NaN
# 919                                                NaN
# 920                                                NaN
# 921                                                NaN
# 922                                                NaN
# 923  Merchandise exports to high-income economies a...
# 924  Merchandise exports to low- and middle-income ...
# 925  Merchandise exports to low- and middle-income ...
# 926  Merchandise exports to low- and middle-income ...
# 927  Merchandise exports to low- and middle-income ...
# 928  Merchandise exports to low- and middle-income ...
# 929  Merchandise exports to low- and middle-income ...
# 930  Merchandise exports to low- and middle-income ...
# 931                                                NaN
# 932  Merchandise exports by the reporting economy a...
# 933  Merchandise exports to low- and middle-income ...
# 934                                                NaN
# 935                                                NaN
# 936                                                NaN
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940                                                NaN
# 941                                                NaN
# 942                                                NaN
# 943                                                NaN
#
#                                        Long definition Unit of measure  \
# 0                                                  NaN             NaN
# 1    Fertilizer consumption measures the quantity o...             NaN
# 2    Agricultural land refers to the share of land ...             NaN
# 3    Agricultural land refers to the share of land ...             NaN
# 4    Arable land (in hectares) includes land define...             NaN
# 5    Arable land (hectares per person) includes lan...             NaN
# 6    Arable land includes land defined by the FAO a...             NaN
# 7    Land under cereal production refers to harvest...             NaN
# 8    Permanent cropland is land cultivated with cro...             NaN
# 9    Forest area is land under natural or planted s...             NaN
# 10   Forest area is land under natural or planted s...             NaN
# 11   Land area is a country's total area, excluding...             NaN
# 12   Production data on cereals relate to crops har...             NaN
# 13   Crop production index shows agricultural produ...             NaN
# 14   Food production index covers food crops that a...             NaN
# 15   Livestock production index includes meat and m...             NaN
# 16   Surface area is a country's total area, includ...             NaN
# 17   Cereal yield, measured as kilograms per hectar...             NaN
# 18   Trade in services is the sum of service export...             NaN
# 19   Communications, computer, information, and oth...             NaN
# 20   Primary income payments refer to employee comp...             NaN
# 21   Imports of goods and services comprise all tra...             NaN
# 22   Insurance and financial services cover various...             NaN
# 23   Goods imports refer to all movable goods (incl...             NaN
# 24   Services refer to economic output of intangibl...             NaN
# 25   Charges for the use of intellectual property a...             NaN
# 26   Imports of goods, services and primary income ...             NaN
# 27   Transport covers all transport services (sea, ...             NaN
# 28   Travel covers goods and services acquired from...             NaN
# 29   Foreign direct investment refers to direct inv...             NaN
# ..                                                 ...             ...
# 914  Agricultural raw materials comprise SITC secti...             NaN
# 915  Food comprises the commodities in SITC section...             NaN
# 916  Fuels comprise the commodities in SITC section...             NaN
# 917  Information and communication technology goods...             NaN
# 918  Insurance and financial services cover freight...             NaN
# 919  Manufactures comprise commodities in SITC sect...             NaN
# 920  Ores and metals comprise the commodities in SI...             NaN
# 921  Merchandise exports to economies in the Arab W...             NaN
# 922  Merchandise exports show the f.o.b. value of g...             NaN
# 923  Merchandise exports to high-income economies a...             NaN
# 924  Merchandise exports to low- and middle-income ...             NaN
# 925  Merchandise exports to low- and middle-income ...             NaN
# 926  Merchandise exports to low- and middle-income ...             NaN
# 927  Merchandise exports to low- and middle-income ...             NaN
# 928  Merchandise exports to low- and middle-income ...             NaN
# 929  Merchandise exports to low- and middle-income ...             NaN
# 930  Merchandise exports to low- and middle-income ...             NaN
# 931  Merchandise exports by the reporting economy r...             NaN
# 932  Merchandise exports by the reporting economy a...             NaN
# 933  Merchandise exports to low- and middle-income ...             NaN
# 934  Export values are the current value of exports...             NaN
# 935  Computer, communications and other services (%...             NaN
# 936  Commercial service exports are total service e...             NaN
# 937  High-technology exports are products with high...             NaN
# 938  High-technology exports are products with high...             NaN
# 939  Transport services (% of commercial service ex...             NaN
# 940  Travel services (% of commercial service expor...             NaN
# 941  Internally displaced persons are defined accor...             NaN
# 942  Intentional homicides are estimates of unlawfu...             NaN
# 943                                                NaN             NaN
#
#     Periodicity Base Period Other notes     ...      \
# 0           NaN         NaN         NaN     ...
# 1        Annual         NaN         NaN     ...
# 2        Annual         NaN         NaN     ...
# 3        Annual         NaN         NaN     ...
# 4        Annual         NaN         NaN     ...
# 5        Annual         NaN         NaN     ...
# 6        Annual         NaN         NaN     ...
# 7        Annual         NaN         NaN     ...
# 8        Annual         NaN         NaN     ...
# 9        Annual         NaN         NaN     ...
# 10       Annual         NaN         NaN     ...
# 11       Annual         NaN         NaN     ...
# 12       Annual         NaN         NaN     ...
# 13       Annual     2004-06         NaN     ...
# 14       Annual     2004-06         NaN     ...
# 15       Annual     2004-06         NaN     ...
# 16       Annual         NaN         NaN     ...
# 17       Annual         NaN         NaN     ...
# 18       Annual         NaN         NaN     ...
# 19       Annual         NaN         NaN     ...
# 20       Annual         NaN         NaN     ...
# 21       Annual         NaN         NaN     ...
# 22       Annual         NaN         NaN     ...
# 23       Annual         NaN         NaN     ...
# 24       Annual         NaN         NaN     ...
# 25       Annual         NaN         NaN     ...
# 26       Annual         NaN         NaN     ...
# 27       Annual         NaN         NaN     ...
# 28       Annual         NaN         NaN     ...
# 29       Annual         NaN         NaN     ...
# ..          ...         ...         ...     ...
# 914      Annual         NaN         NaN     ...
# 915      Annual         NaN         NaN     ...
# 916      Annual         NaN         NaN     ...
# 917      Annual         NaN         NaN     ...
# 918      Annual         NaN         NaN     ...
# 919      Annual         NaN         NaN     ...
# 920      Annual         NaN         NaN     ...
# 921      Annual         NaN         NaN     ...
# 922      Annual         NaN         NaN     ...
# 923      Annual         NaN         NaN     ...
# 924      Annual         NaN         NaN     ...
# 925      Annual         NaN         NaN     ...
# 926      Annual         NaN         NaN     ...
# 927      Annual         NaN         NaN     ...
# 928      Annual         NaN         NaN     ...
# 929      Annual         NaN         NaN     ...
# 930      Annual         NaN         NaN     ...
# 931      Annual         NaN         NaN     ...
# 932      Annual         NaN         NaN     ...
# 933      Annual         NaN         NaN     ...
# 934      Annual        2000         NaN     ...
# 935      Annual         NaN         NaN     ...
# 936      Annual         NaN         NaN     ...
# 937      Annual         NaN         NaN     ...
# 938      Annual         NaN         NaN     ...
# 939      Annual         NaN         NaN     ...
# 940      Annual         NaN         NaN     ...
# 941      Annual         NaN         NaN     ...
# 942      Annual         NaN         NaN     ...
# 943         NaN         NaN         NaN     ...
#
#     Notes from original source  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# ..                         ...
# 914                        NaN
# 915                        NaN
# 916                        NaN
# 917                        NaN
# 918                        NaN
# 919                        NaN
# 920                        NaN
# 921                        NaN
# 922                        NaN
# 923                        NaN
# 924                        NaN
# 925                        NaN
# 926                        NaN
# 927                        NaN
# 928                        NaN
# 929                        NaN
# 930                        NaN
# 931                        NaN
# 932                        NaN
# 933                        NaN
# 934                        NaN
# 935                        NaN
# 936                        NaN
# 937                        NaN
# 938                        NaN
# 939                        NaN
# 940                        NaN
# 941                        NaN
# 942                        NaN
# 943                        NaN
#
#                                       General comments  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18   Note: Data are based on the sixth edition of t...
# 19   Note: Data are based on the sixth edition of t...
# 20   Note: Data are based on the sixth edition of t...
# 21   Note: Data are based on the sixth edition of t...
# 22   Note: Data are based on the sixth edition of t...
# 23   Note: Data are based on the sixth edition of t...
# 24   Note: Data are based on the sixth edition of t...
# 25   Note: Data are based on the sixth edition of t...
# 26   Note: Data are based on the sixth edition of t...
# 27   Note: Data are based on the sixth edition of t...
# 28   Note: Data are based on the sixth edition of t...
# 29   Note: Data starting from 2005 are based on the...
# ..                                                 ...
# 914  Merchandise export shares may not sum to 100 p...
# 915  Merchandise export shares may not sum to 100 p...
# 916  Merchandise export shares may not sum to 100 p...
# 917                                                NaN
# 918                                                NaN
# 919  Merchandise export shares may not sum to 100 p...
# 920  Merchandise export shares may not sum to 100 p...
# 921                                                NaN
# 922                                                NaN
# 923                                                NaN
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
# 929                                                NaN
# 930                                                NaN
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
# 936                                                NaN
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940                                                NaN
# 941                                                NaN
# 942                                                NaN
# 943                                                NaN
#
#                                                 Source  \
# 0                                                  NaN
# 1    Food and Agriculture Organization, electronic ...
# 2    Food and Agriculture Organization, electronic ...
# 3    Food and Agriculture Organization, electronic ...
# 4    Food and Agriculture Organization, electronic ...
# 5    Food and Agriculture Organization, electronic ...
# 6    Food and Agriculture Organization, electronic ...
# 7    Food and Agriculture Organization, electronic ...
# 8    Food and Agriculture Organization, electronic ...
# 9    Food and Agriculture Organization, electronic ...
# 10   Food and Agriculture Organization, electronic ...
# 11   Food and Agriculture Organization, electronic ...
# 12   Food and Agriculture Organization, electronic ...
# 13   Food and Agriculture Organization, electronic ...
# 14   Food and Agriculture Organization, electronic ...
# 15   Food and Agriculture Organization, electronic ...
# 16   Food and Agriculture Organization, electronic ...
# 17   Food and Agriculture Organization, electronic ...
# 18   International Monetary Fund, Balance of Paymen...
# 19   International Monetary Fund, Balance of Paymen...
# 20   International Monetary Fund, Balance of Paymen...
# 21   International Monetary Fund, Balance of Paymen...
# 22   International Monetary Fund, Balance of Paymen...
# 23   International Monetary Fund, Balance of Paymen...
# 24   International Monetary Fund, Balance of Paymen...
# 25   International Monetary Fund, Balance of Paymen...
# 26   International Monetary Fund, Balance of Paymen...
# 27   International Monetary Fund, Balance of Paymen...
# 28   International Monetary Fund, Balance of Paymen...
# 29   International Monetary Fund, Balance of Paymen...
# ..                                                 ...
# 914  World Bank staff estimates through the WITS pl...
# 915  World Bank staff estimates through the WITS pl...
# 916  World Bank staff estimates through the WITS pl...
# 917  United Nations Conference on Trade and Develop...
# 918  International Monetary Fund, Balance of Paymen...
# 919  World Bank staff estimates through the WITS pl...
# 920  World Bank staff estimates through the WITS pl...
# 921  World Bank staff estimates based data from Int...
# 922                          World Trade Organization.
# 923  World Bank staff estimates based data from Int...
# 924  World Bank staff estimates based data from Int...
# 925  World Bank staff estimates based data from Int...
# 926  World Bank staff estimates based data from Int...
# 927  World Bank staff estimates based data from Int...
# 928  World Bank staff estimates based data from Int...
# 929  World Bank staff estimates based data from Int...
# 930  World Bank staff estimates based data from Int...
# 931  World Bank staff estimates based data from Int...
# 932  World Bank staff estimates based data from Int...
# 933  World Bank staff estimates based data from Int...
# 934  United Nations Conference on Trade and Develop...
# 935  International Monetary Fund, Balance of Paymen...
# 936  International Monetary Fund, Balance of Paymen...
# 937  United Nations, Comtrade database through the ...
# 938  United Nations, Comtrade database through the ...
# 939  International Monetary Fund, Balance of Paymen...
# 940  International Monetary Fund, Balance of Paymen...
# 941  The Internal Displacement Monitoring Centre (h...
# 942  UN Office on Drugs and Crime's International H...
# 943                                                NaN
#
#                    Statistical concept and methodology  \
# 0                                                  NaN
# 1    Fertilizer consumption measures the quantity o...
# 2    Agricultural land constitutes only a part of a...
# 3    Agriculture is still a major sector in many ec...
# 4    Temporary fallow land refers to land left fall...
# 5    Temporary fallow land refers to land left fall...
# 6    Temporary fallow land refers to land left fall...
# 7    Cereals production includes wheat, rice, maize...
# 8    The data on Permanent cropland and land area a...
# 9    Forest is determined both by the presence of t...
# 10   Forest is determined both by the presence of t...
# 11   Total land area does not include inland water ...
# 12   A cereal is a grass cultivated for the edible ...
# 13   The agricultural production index is prepared ...
# 14   The agricultural production index is prepared ...
# 15   The agricultural production index is prepared ...
# 16   Total land area includes inland water bodies s...
# 17   A cereal is a grass cultivated for the edible ...
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21   The balance of payments (BoP) is a double-entr...
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29   Data on equity flows are based on balance of p...
# ..                                                 ...
# 914  The classification of commodity groups is base...
# 915  The classification of commodity groups is base...
# 916  The classification of commodity groups is base...
# 917  Information and communication technology goods...
# 918  The balance of payments (BoP) is a double-entr...
# 919  The classification of commodity groups is base...
# 920  The classification of commodity groups is base...
# 921                                                NaN
# 922  Merchandise trade data are from customs report...
# 923                                                NaN
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
# 929                                                NaN
# 930                                                NaN
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935  The balance of payments (BoP) is a double-entr...
# 936  The balance of payments (BoP) is a double-entr...
# 937  High technology products are defined according...
# 938  The method for determining high-technology exp...
# 939  The balance of payments (BoP) is a double-entr...
# 940  The balance of payments (BoP) is a double-entr...
# 941  Internally displaced persons are "persons or g...
# 942  The definitions used to produce data are in li...
# 943                                                NaN
#
#                                  Development relevance Related source links  \
# 0                                                  NaN                  NaN
# 1    Factors such as the green revolution, has led ...                  NaN
# 2    Agricultural land covers more than one-third o...                  NaN
# 3    Agricultural land covers more than one-third o...                  NaN
# 4    Agricultural land covers more than one-third o...                  NaN
# 5    Agricultural land covers about one-third of th...                  NaN
# 6    Agricultural land covers more than one-third o...                  NaN
# 7    The cultivation of cereals varies widely in di...                  NaN
# 8    Agricultural land covers more than one-third o...                  NaN
# 9    As threats to biodiversity mount, the internat...                  NaN
# 10   As threats to biodiversity mount, the internat...                  NaN
# 11   Land area is particularly important for unders...                  NaN
# 12   The Food and Agriculture Organization (FAO) es...                  NaN
# 13   The commodities covered in the computation of ...                  NaN
# 14   The commodities covered in the computation of ...                  NaN
# 15   The commodities covered in the computation of ...                  NaN
# 16   Total surface area is particularly important f...                  NaN
# 17   In developed countries, cereal crops are unive...                  NaN
# 18                                                 NaN                  NaN
# 19                                                 NaN                  NaN
# 20                                                 NaN                  NaN
# 21   The balance of payments records an economy’s t...                  NaN
# 22                                                 NaN                  NaN
# 23                                                 NaN                  NaN
# 24                                                 NaN                  NaN
# 25                                                 NaN                  NaN
# 26                                                 NaN                  NaN
# 27                                                 NaN                  NaN
# 28                                                 NaN                  NaN
# 29   Private financial flows - equity and debt - ac...                  NaN
# ..                                                 ...                  ...
# 914                                                NaN                  NaN
# 915                                                NaN                  NaN
# 916                                                NaN                  NaN
# 917  The digital and information revolution has cha...                  NaN
# 918  Trade in services differs from trade in goods ...                  NaN
# 919                                                NaN                  NaN
# 920                                                NaN                  NaN
# 921                                                NaN                  NaN
# 922                                                NaN                  NaN
# 923  Low- and middle-income economies are an increa...                  NaN
# 924  Although global integration has increased, low...                  NaN
# 925                                                NaN                  NaN
# 926                                                NaN                  NaN
# 927                                                NaN                  NaN
# 928                                                NaN                  NaN
# 929                                                NaN                  NaN
# 930                                                NaN                  NaN
# 931                                                NaN                  NaN
# 932                                                NaN                  NaN
# 933  The relative importance of intraregional trade...                  NaN
# 934                                                NaN                  NaN
# 935  Trade in services differs from trade in goods ...                  NaN
# 936  Trade in services differs from trade in goods ...                  NaN
# 937  The OECD has developed a four-way classificati...                  NaN
# 938  The OECD has developed a four-way classificati...                  NaN
# 939  Trade in services differs from trade in goods ...                  NaN
# 940  Trade in services differs from trade in goods ...                  NaN
# 941  Although all persons affected by conflict and/...                  NaN
# 942  In some regions, organized crime, drug traffic...                  NaN
# 943                                                NaN                  NaN
#
#     Other web links Related indicators  License Type Unnamed: 20
# 0               NaN                NaN           NaN         NaN
# 1               NaN                NaN     CC BY-4.0         NaN
# 2               NaN                NaN     CC BY-4.0         NaN
# 3               NaN                NaN     CC BY-4.0         NaN
# 4               NaN                NaN     CC BY-4.0         NaN
# 5               NaN                NaN     CC BY-4.0         NaN
# 6               NaN                NaN     CC BY-4.0         NaN
# 7               NaN                NaN     CC BY-4.0         NaN
# 8               NaN                NaN     CC BY-4.0         NaN
# 9               NaN                NaN     CC BY-4.0         NaN
# 10              NaN                NaN     CC BY-4.0         NaN
# 11              NaN                NaN     CC BY-4.0         NaN
# 12              NaN                NaN     CC BY-4.0         NaN
# 13              NaN                NaN     CC BY-4.0         NaN
# 14              NaN                NaN     CC BY-4.0         NaN
# 15              NaN                NaN     CC BY-4.0         NaN
# 16              NaN                NaN     CC BY-4.0         NaN
# 17              NaN                NaN     CC BY-4.0         NaN
# 18              NaN                NaN     CC BY-4.0         NaN
# 19              NaN                NaN     CC BY-4.0         NaN
# 20              NaN                NaN     CC BY-4.0         NaN
# 21              NaN                NaN     CC BY-4.0         NaN
# 22              NaN                NaN     CC BY-4.0         NaN
# 23              NaN                NaN     CC BY-4.0         NaN
# 24              NaN                NaN     CC BY-4.0         NaN
# 25              NaN                NaN     CC BY-4.0         NaN
# 26              NaN                NaN     CC BY-4.0         NaN
# 27              NaN                NaN     CC BY-4.0         NaN
# 28              NaN                NaN     CC BY-4.0         NaN
# 29              NaN                NaN     CC BY-4.0         NaN
# ..              ...                ...           ...         ...
# 914             NaN                NaN     CC BY-4.0         NaN
# 915             NaN                NaN     CC BY-4.0         NaN
# 916             NaN                NaN     CC BY-4.0         NaN
# 917             NaN                NaN     CC BY-4.0         NaN
# 918             NaN                NaN     CC BY-4.0         NaN
# 919             NaN                NaN     CC BY-4.0         NaN
# 920             NaN                NaN     CC BY-4.0         NaN
# 921             NaN                NaN     CC BY-4.0         NaN
# 922             NaN                NaN     CC BY-4.0         NaN
# 923             NaN                NaN     CC BY-4.0         NaN
# 924             NaN                NaN     CC BY-4.0         NaN
# 925             NaN                NaN     CC BY-4.0         NaN
# 926             NaN                NaN     CC BY-4.0         NaN
# 927             NaN                NaN     CC BY-4.0         NaN
# 928             NaN                NaN     CC BY-4.0         NaN
# 929             NaN                NaN     CC BY-4.0         NaN
# 930             NaN                NaN     CC BY-4.0         NaN
# 931             NaN                NaN     CC BY-4.0         NaN
# 932             NaN                NaN     CC BY-4.0         NaN
# 933             NaN                NaN     CC BY-4.0         NaN
# 934             NaN                NaN     CC BY-4.0         NaN
# 935             NaN                NaN     CC BY-4.0         NaN
# 936             NaN                NaN     CC BY-4.0         NaN
# 937             NaN                NaN     CC BY-4.0         NaN
# 938             NaN                NaN     CC BY-4.0         NaN
# 939             NaN                NaN     CC BY-4.0         NaN
# 940             NaN                NaN     CC BY-4.0         NaN
# 941             NaN                NaN     CC BY-4.0         NaN
# 942             NaN                NaN     CC BY-4.0         NaN
# 943             NaN                NaN           NaN         NaN
#
# [944 rows x 22 columns]

# %%
# Reduce DataFrame to chosen columns
keep_columns = pd.DataFrame(['Country Name', 'Happy Planet Index'])
chosen_columns = pd.read_csv('../data/raw_data/WDISeries_Choice.csv')
chosen_columns = chosen_columns['Series Code'][chosen_columns['Choice'] == True]
chosen_columns.reset_index().drop('index', axis = 1)
keep_columns = pd.concat([keep_columns, chosen_columns], ignore_index = True).rename(columns = {0:'Indicator Code'})
keep_columns = keep_columns['Indicator Code'].tolist()

drop_columns = []
for col in wdi_hpi_2016_df.columns:
    if not col in keep_columns:
        drop_columns.append(col)

wdi_hpi_2016_df = wdi_hpi_2016_df.drop(drop_columns, axis = 1)

wdi_hpi_2016_df
# Out:
#                Country Name  AG.CON.FERT.ZS  AG.LND.AGRI.ZS  AG.LND.CROP.ZS  \
# 0               Afghanistan       12.182300       58.067580        0.277242
# 1                   Albania      126.138483       43.127735        3.036496
# 2                   Algeria       22.315273       17.365539        0.425487
# 3                 Argentina       50.336331       54.335712        0.365405
# 4                   Armenia      110.495136       58.897086        2.037232
# 5                 Australia       68.103696       48.241944        0.042902
# 6                   Austria      141.837426       32.356676        0.810320
# 7                Bangladesh      289.402272       70.632327        6.376277
# 8                   Belarus      146.618640       42.035489        0.548308
# 9                   Belgium      318.484804       44.610305        0.759577
# 10                   Belize      466.248861        7.014467        1.402893
# 11                    Benin       14.747607       33.256474        4.434197
# 12                   Bhutan       13.253300       13.606334        0.157299
# 13                  Bolivia        7.609475       34.787224        0.214160
# 14   Bosnia and Herzegovina      131.800031       43.144531        2.031250
# 15                 Botswana       89.572417       45.633017        0.003529
# 16                   Brazil      186.096115       33.924533        0.786060
# 17                 Bulgaria      125.543387       46.250921        1.298821
# 18             Burkina Faso       21.773517       44.225146        0.365497
# 19                  Burundi        5.424258       79.166667       13.629283
# 20                 Cambodia       17.393597       30.903014        0.878087
# 21                 Cameroon        9.667529       20.625754        3.278966
# 22                   Canada       87.625097        6.891838        0.510694
# 23                     Chad             NaN       39.656131        0.027795
# 24                    Chile      293.844818       21.171650        0.614634
# 25                    China      503.322119       56.212313        1.704265
# 26                 Colombia      659.452061       40.257415        1.717891
# 27                  Comoros             NaN       71.466951       28.479311
# 28              Congo, Rep.        1.844091       31.118594        0.225476
# 29               Costa Rica      604.885835       34.459459        6.110458
# ..                      ...             ...             ...             ...
# 109            Sierra Leone             NaN       54.710446        2.285952
# 110         Slovak Republic      125.762435       39.226290        0.374376
# 111                Slovenia      258.940607       30.656340        2.672525
# 112            South Africa       58.511600       79.830021        0.340453
# 113                   Spain      143.966129       52.577247        9.399857
# 114               Sri Lanka      131.922626       43.693191       15.946420
# 115                Suriname      217.708609        0.557692        0.038462
# 116                  Sweden       96.336442        7.442734        0.012276
# 117             Switzerland      214.407293       38.363446        0.633920
# 118    Syrian Arab Republic        7.551489       75.810053        5.832380
# 119              Tajikistan       81.377397       34.137906        0.958282
# 120                Tanzania       12.604495       44.761797        2.427184
# 121                Thailand      161.710310       43.277418        8.808158
# 122                    Togo       11.026125       70.233499        3.125575
# 123     Trinidad and Tobago      356.000000       10.526316        4.288499
# 124                 Tunisia       59.251282       64.836509       15.010299
# 125                  Turkey      137.704921       49.799254        4.325455
# 126            Turkmenistan             NaN       72.006469        0.127679
# 127                  Uganda        1.910848       71.888091       10.971474
# 128                 Ukraine       52.747437       71.665314        1.548447
# 129          United Kingdom      252.903672       71.714878        0.192783
# 130           United States      138.594848       44.369068        0.284233
# 131                 Uruguay      143.668461       82.559705        0.222832
# 132              Uzbekistan      232.703182       62.929008        0.869770
# 133                 Vanuatu             NaN       15.340443       10.254307
# 134           Venezuela, RB      183.467529       24.488408        0.793606
# 135                 Vietnam      429.784831       39.275002       14.635405
# 136             Yemen, Rep.       16.396546       44.597231        0.564426
# 137                  Zambia       89.594070       32.063923        0.048427
# 138                Zimbabwe       22.900000       41.876696        0.258498
#
#      AG.LND.FRST.ZS  AG.PRD.FOOD.XD  AG.PRD.LVSK.XD  BG.GSR.NFSV.GD.ZS  \
# 0          2.067825          125.41           98.70           8.214071
# 1         28.121897          150.93          113.07          37.276873
# 2          0.824439          151.62          147.06           8.941519
# 3          9.798406          129.11          107.00           6.331674
# 4         11.668423          135.37          143.85          31.207718
# 5         16.258278          105.58          102.02           9.967677
# 6         46.905713          101.29          108.27          28.130637
# 7         10.957978          145.31          135.88           5.122781
# 8         42.630106          133.94          147.85          23.605768
# 9         22.583885           84.89           81.32          44.952060
# 10        59.679089           94.19          118.05          41.767195
# 11        37.788223          161.65          136.32          11.880402
# 12        72.484537          102.11           92.82          15.911989
# 13        50.286163          146.43          135.44          12.087602
# 14        42.675781          125.39          119.68          14.092026
# 15        18.946941          119.84          119.04          11.953832
# 16        58.931054          136.50          127.00           5.402699
# 17        35.373986          129.85           84.39          26.426350
# 18        19.335527          127.42           84.19          15.473026
# 19        10.926792          119.85          140.58           9.716459
# 20        52.852932          187.64           89.23          32.061679
# 21        39.339130          181.65          125.40          11.969096
# 22        38.161547          117.66           83.25          12.043526
# 23         3.770966          155.20          117.13                NaN
# 24        24.256925          114.79          110.55           8.934108
# 25        22.353942          139.03          130.43           5.835489
# 26        52.703938          116.67          115.61           6.743245
# 27        19.666844          108.68          109.39          15.922503
# 28        65.354611          138.11          177.07          27.177619
# 29        54.567175          131.03          127.21          20.932174
# ..              ...             ...             ...                ...
# 109       43.053479          201.22          214.46          19.853493
# 110       40.353576          101.77           76.90          20.145463
# 111       61.970012           88.70           89.62          27.448267
# 112        7.617737          116.66          131.10           9.886579
# 113       36.936210          103.90           95.35          15.920979
# 114       32.903842          131.27          112.83          13.831130
# 115       98.257694          156.91          125.11          21.034875
# 116       68.922933           99.64           92.60          26.079241
# 117       31.830145          102.84          106.00          32.369914
# 118        2.673855           85.25           82.36                NaN
# 119        2.971396          155.46          128.04           8.715418
# 120       51.578234          168.95          132.78          11.603909
# 121       32.157607          114.55          131.25          26.020888
# 122        3.092480          145.00          143.11          20.968111
# 123       46.023393           96.14          120.58          16.544863
# 124        6.766220          117.64          131.16          14.974136
# 125       15.354651          134.45          163.74           6.986857
# 126        8.782159          113.04          117.55                NaN
# 127        9.683822           98.31          131.64          16.332259
# 128       16.708039          169.07           97.46          26.144010
# 129       13.065763          103.82          106.58          21.915470
# 130       33.929786          122.32          109.70           6.789208
# 131       10.671580          116.65          100.83          14.221145
# 132        7.542971          157.08          134.03           6.540169
# 133       36.095160          124.05          111.26          59.777214
# 134       52.739189          107.73          129.80                NaN
# 135       48.060115          136.18          151.37          14.252994
# 136        1.039832          141.69          157.93           6.211076
# 137       65.199153          179.77          200.58          10.872915
# 138       35.542457           88.75          106.25           8.080966
#
#      BM.GSR.CMCP.ZS  BM.GSR.INSF.ZS         ...          SH.H2O.BASW.ZS  \
# 0         11.539220        1.514437         ...               64.286484
# 1         13.357326        2.139191         ...               91.020370
# 2         60.278868        2.153545         ...               93.515851
# 3         31.524771        2.931377         ...               99.078375
# 4         10.972255        3.670673         ...               99.898536
# 5         26.699697        3.812020         ...               99.969972
# 6         44.644297        5.861771         ...              100.000000
# 7         13.063639       11.458420         ...               96.882530
# 8         45.339389        5.899941         ...               96.474184
# 9         56.161278        7.070418         ...               99.999999
# 10        28.156110       16.000442         ...               97.584540
# 11        21.587678        2.203317         ...               66.320240
# 12        47.936558        2.740508         ...               97.207625
# 13        41.308723        4.951982         ...               92.176899
# 14        17.792549        8.985122         ...               96.151262
# 15        35.893260        1.463211         ...               89.404440
# 16        59.980736        3.491714         ...               97.847986
# 17        32.804694        8.412019         ...               99.148175
# 18        25.964281       17.840128         ...               48.267717
# 19        26.759414        2.768985         ...               60.204152
# 20        15.044309        6.220277         ...               76.945374
# 21        27.568587        8.223659         ...               60.155720
# 22        39.495294       12.406986         ...               99.412624
# 23              NaN             NaN         ...               38.852591
# 24        41.662603        8.646163         ...               99.622180
# 25        21.721538        3.384937         ...               92.304047
# 26        26.234110       13.071494         ...               96.961806
# 27         2.048559        8.164242         ...               80.148853
# 28        16.335598        7.381441         ...               72.186656
# 29        33.689224       11.431169         ...               99.699764
# ..              ...             ...         ...                     ...
# 109       55.701656        7.994451         ...               59.563143
# 110       44.923286        3.187940         ...               99.787517
# 111       48.207776        5.562845         ...               99.534383
# 112       39.056972        3.864562         ...               92.270312
# 113       42.626784        8.836851         ...               99.926506
# 114       14.250974       11.552955         ...               88.835985
# 115       62.628185        6.504091         ...               94.519398
# 116       55.395962        3.793399         ...               99.999996
# 117       68.110134        5.230319         ...              100.000000
# 118             NaN             NaN         ...               97.059075
# 119       20.564951        0.749371         ...               79.625850
# 120       15.206765        1.352140         ...               54.847537
# 121       39.730092        4.801115         ...               99.373805
# 122       12.952587       10.736702         ...               64.021439
# 123       59.659726       10.287866         ...               98.184962
# 124       23.660852        8.526628         ...               95.992403
# 125       28.373702       14.577234         ...               98.880874
# 126             NaN             NaN         ...               98.703724
# 127       35.743121        3.875671         ...               47.665631
# 128       28.422109        5.485408         ...               93.724079
# 129       37.304446        9.814126         ...              100.000000
# 130       41.851551       14.825702         ...               99.263709
# 131       44.355465        3.856719         ...               99.322892
# 132        1.440831        3.466844         ...               97.681271
# 133        0.887142        3.334985         ...               90.661524
# 134       48.817568        3.821791         ...               95.778367
# 135             NaN             NaN         ...               93.990123
# 136       30.265425       12.361489         ...               63.322034
# 137       16.689237       10.354688         ...               59.238564
# 138       44.666960             NaN         ...               64.511616
#
#      SH.H2O.SMDW.ZS  SH.MED.PHYS.ZS  SH.STA.BASS.ZS  SP.DYN.LE00.IN  \
# 0               NaN          0.2840       42.054183       63.763000
# 1         69.984329          1.1998       97.704877       78.194000
# 2               NaN          1.8300       87.542316       76.298000
# 3               NaN             NaN       94.258505       76.221000
# 4         83.005976             NaN       93.406972       74.640000
# 5               NaN          3.5874       99.991152       82.448780
# 6         98.907808          5.1441       99.974814       81.641463
# 7         55.491263          0.4822       47.005803       71.785000
# 8         94.497432             NaN       97.777751       73.826829
# 9         99.523184          3.3234       99.486058       81.439024
# 10              NaN             NaN       87.534776       74.219000
# 11              NaN          0.1572       16.351138       60.885000
# 12        35.997319          0.3748       68.282484       70.781000
# 13              NaN          1.6111       58.800008       70.626000
# 14        88.833356             NaN       95.336149       76.998000
# 15              NaN          0.3688       76.017310       68.178000
# 16              NaN             NaN       87.426360       75.230000
# 17        96.967338             NaN       85.993306       74.812195
# 18              NaN          0.0600       19.126279       60.354000
# 19              NaN          0.0500       45.851019       60.528000
# 20        25.245143             NaN       56.601501       68.977000
# 21              NaN             NaN       38.847405       58.063000
# 22        98.813498          2.5668       99.324530       82.142244
# 23              NaN          0.0475        8.583369       53.438000
# 24        98.463965          1.0800      100.000000       79.779000
# 25              NaN             NaN       83.235173       76.210000
# 26        72.997898          2.0036       88.586994       76.732000
# 27              NaN             NaN       35.834892       63.700000
# 28        44.769632             NaN       19.548053       63.556000
# 29        93.703901             NaN       97.548977       79.738000
# ..              ...             ...             ...             ...
# 109        9.533970             NaN       15.293042       53.444000
# 110       99.697821          2.4643       97.931704       77.165854
# 111       97.845737          2.9953       99.109442       81.175610
# 112             NaN          0.8024       74.824878       63.153000
# 113       98.460785          4.0691       99.904286       83.329268
# 114             NaN          1.0578       95.107030       76.482000
# 115             NaN             NaN       84.140522       71.358000
# 116       99.939996          5.3996       99.297864       82.307317
# 117       95.455405          4.2363       99.890363       83.602439
# 118             NaN          1.2200       91.396032       70.315000
# 119       47.685679             NaN       96.575670       70.397000
# 120             NaN             NaN       28.390380       63.844000
# 121             NaN          0.4457       98.396446       76.403000
# 122             NaN             NaN       15.712305       60.220000
# 123             NaN             NaN       93.398906       73.100000
# 124       92.399273          1.2722       90.880128       76.115000
# 125             NaN             NaN       97.246443       76.860000
# 126       93.005601             NaN       98.272035       67.835000
# 127        6.951530             NaN       18.451233       61.986000
# 128       91.942266             NaN       96.220861       71.476341
# 129       99.988778          2.7959       99.111421       81.156098
# 130       98.996310          2.5948       99.969812       78.539024
# 131             NaN          3.9329       96.401180       77.498000
# 132       58.881467             NaN      100.000000       71.171000
# 133       43.842476          0.1706       36.088024       70.021000
# 134             NaN             NaN       93.935019       72.405000
# 135             NaN          0.8199       81.855704       75.172000
# 136             NaN             NaN       58.772984       66.087000
# 137             NaN          0.0913       26.086491       62.464000
# 138             NaN             NaN       36.891731       60.294000
#
#      SP.POP.GROW  ST.INT.ARVL  ST.INT.DPRT  ST.INT.XPND.MP.ZS  \
# 0       2.778317          NaN          NaN           1.214557
# 1      -0.159880    4070000.0    4852000.0          24.589211
# 2       2.051355    2039000.0    4530000.0           0.923644
# 3       1.057182    6655000.0   10446000.0          15.551549
# 4       0.361431    1260000.0    1263000.0          24.774536
# 5       1.561940    8269000.0   10380000.0          12.605527
# 6       1.081396   28121000.0   11534000.0           6.046445
# 7       1.091300          NaN          NaN           1.750125
# 8       0.125511   10935400.0     467000.0           2.970743
# 9       0.506300    7481000.0   13372000.0           5.780736
# 10      2.047696     386000.0          NaN           4.859470
# 11      2.761409     267000.0          NaN           2.798400
# 12      1.206227     210000.0          NaN           4.202671
# 13      1.480133     959000.0    1048000.0           8.898198
# 14     -1.264581     778000.0          NaN           2.300987
# 15      1.832853    1574000.0          NaN           3.674145
# 16      0.823748    6547000.0    8592000.0           8.390243
# 17     -0.701382    8252000.0    5392000.0           5.148553
# 18      2.915319     152000.0          NaN           4.328927
# 19      3.177016     187000.0          NaN           3.774112
# 20      1.565227    5012000.0    1434000.0           4.604254
# 21      2.660495     994000.0          NaN          11.561708
# 22      1.132349   19971000.0   31278000.0           5.593259
# 23      3.143960      98000.0      56000.0                NaN
# 24      1.325202    5641000.0    3553000.0           3.978482
# 25      0.541479   59270000.0  135130000.0          12.877864
# 26      1.360061    3317000.0    3795000.0           8.846781
# 27      2.310060      26800.0          NaN                NaN
# 28      2.539586     224000.0          NaN           6.272246
# 29      1.057570    2925000.0    1036000.0           5.792707
# ..           ...          ...          ...                ...
# 109     2.164441      55000.0      92000.0           2.600079
# 110     0.128922    2027000.0    3095000.0           2.979368
# 111     0.073197    3032000.0    2853000.0           3.630884
# 112     1.464829   10044000.0          NaN           5.991557
# 113     0.083370   75315000.0   15405000.0           5.235010
# 114     1.104984    2051000.0    1448000.0           9.790236
# 115     1.022223     256000.0          NaN           6.579465
# 116     1.256454    6782000.0          NaN           7.370420
# 117     1.092031    9205000.0   13857000.0           5.166115
# 118    -3.066274          NaN          NaN                NaN
# 119     2.448490     344000.0      22000.0           0.840462
# 120     3.000523    1233000.0          NaN           9.483022
# 121     0.373053   32530000.0    8204000.0           5.093054
# 122     2.518742     338000.0          NaN           2.293095
# 123     0.526659     409000.0          NaN           2.342036
# 124     1.102996    5724000.0    1830000.0           3.848483
# 125     1.632251   30289000.0    7892000.0           2.352583
# 126     1.729433          NaN          NaN                NaN
# 127     3.652644    1323000.0     568000.0           4.431074
# 128    -0.331381   13333000.0   24668000.0          12.020358
# 129     0.714030   35814000.0   70815000.0          10.831223
# 130     0.723401   76407000.0   80226000.0           5.919369
# 131     0.354674    3037000.0    1715000.0           9.653701
# 132     1.738849    2027000.0          NaN                NaN
# 133     2.620905      95100.0      25000.0                NaN
# 134    -0.786448     601000.0    1530000.0          11.313444
# 135     1.032287   10013000.0          NaN           2.468499
# 136     2.498247          NaN          NaN           0.678286
# 137     3.003346     956000.0          NaN           5.332950
# 138     1.549759    2168000.0    3192000.0           6.317394
#
#      Happy Planet Index
# 0             20.225350
# 1             36.766874
# 2             33.300543
# 3             35.190244
# 4             25.666417
# 5             21.228966
# 6             30.478224
# 7             38.390694
# 8             21.718916
# 9             23.726523
# 10            33.839843
# 11            13.422365
# 12            28.623233
# 13            23.321493
# 14            25.285497
# 15            16.605083
# 16            34.344975
# 17            20.440789
# 18            17.886188
# 19            15.576159
# 20            25.649373
# 21            16.698237
# 22            23.941834
# 23            12.777156
# 24            31.665522
# 25            25.726420
# 26            40.695011
# 27            23.100989
# 28            18.812712
# 29            44.714071
# ..                  ...
# 109           15.264650
# 110           28.228897
# 111           24.638840
# 112           15.868992
# 113           35.958977
# 114           33.791776
# 115           25.447157
# 116           28.034925
# 117           34.330970
# 118           19.100371
# 119           34.249597
# 120           22.138379
# 121           37.290105
# 122           13.233269
# 123           15.718347
# 124           26.197141
# 125           26.424565
# 126           14.608544
# 127           19.419102
# 128           26.383162
# 129           31.909286
# 130           20.746378
# 131           36.134280
# 132           29.126307
# 133           40.570099
# 134           33.569960
# 135           40.307589
# 136           22.754269
# 137           25.224246
# 138           22.112535
#
# [139 rows x 100 columns]

# %%
print(wdi_hpi_2016_df['SH.H2O.SMDW.ZS'].mean(),'\n')
wdi_hpi_2016_df.mean()
# Out:
# 77.22718636250488
# AG.CON.FERT.ZS          1.975917e+02
# AG.LND.AGRI.ZS          4.286560e+01
# AG.LND.CROP.ZS          3.363702e+00
# AG.LND.FRST.ZS          2.994156e+01
# AG.PRD.FOOD.XD          1.239777e+02
# AG.PRD.LVSK.XD          1.189442e+02
# BG.GSR.NFSV.GD.ZS       2.397951e+01
# BM.GSR.CMCP.ZS          3.599249e+01
# BM.GSR.INSF.ZS          7.619859e+00
# BM.GSR.TRAN.ZS          3.313865e+01
# BM.KLT.DINV.WD.GD.ZS    2.401294e+00
# BX.GSR.MRCH.CD          1.062062e+11
# BX.GSR.NFSV.CD          3.428883e+10
# BX.GSR.ROYL.CD          3.072441e+09
# BX.KLT.DINV.WD.GD.ZS    4.895063e+00
# CM.MKT.INDX.ZG          5.305658e+00
# DT.DOD.DIMF.CD          1.146466e+09
# DT.DOD.DSTC.IR.ZS       5.256618e+01
# EG.ELC.ACCS.ZS          8.424617e+01
# EN.POP.DNST             1.864113e+02
# ER.LND.PTLD.ZS          1.811230e+01
# ER.MRN.PTMR.ZS          6.842138e+00
# ER.PTD.TOTL.ZS          1.353181e+01
# FB.ATM.TOTL.P5          5.434421e+01
# FB.BNK.CAPA.ZS          1.018189e+01
# FB.CBK.BRCH.P5          1.771323e+01
# FD.AST.PRVT.GD.ZS       5.663540e+01
# FP.CPI.TOTL             1.515093e+02
# FP.CPI.TOTL.ZG          5.325913e+00
# GB.XPD.RSDV.GD.ZS       1.117397e+00
#                             ...
# SE.ENR.PRSC.FM.ZS       9.931939e-01
# SE.ENR.SECO.FM.ZS       9.923471e-01
# SE.ENR.TERT.FM.ZS       1.180197e+00
# SE.PRE.DURS             2.768116e+00
# SE.PRE.ENRL.TC.ZS       1.963245e+01
# SE.PRE.ENRR             6.835990e+01
# SE.PRE.ENRR.FE          6.828905e+01
# SE.PRE.ENRR.MA          6.843204e+01
# SE.PRM.AGES             6.115942e+00
# SE.PRM.CMPT.FE.ZS       9.238406e+01
# SE.PRM.CMPT.MA.ZS       9.209847e+01
# SE.PRM.CMPT.ZS          9.223298e+01
# SE.SEC.ENRL.TC.ZS       1.596452e+01
# SE.TER.ENRR             5.066955e+01
# SE.TER.ENRR.FE          5.620799e+01
# SE.TER.ENRR.MA          4.516952e+01
# SE.XPD.TOTL.GB.ZS       1.544982e+01
# SE.XPD.TOTL.GD.ZS       4.697483e+00
# SH.ALC.PCAP.MA.LI       1.124855e+01
# SH.DYN.MORT             2.839130e+01
# SH.H2O.BASW.ZS          8.816070e+01
# SH.H2O.SMDW.ZS          7.722719e+01
# SH.MED.PHYS.ZS          2.111806e+00
# SH.STA.BASS.ZS          7.565842e+01
# SP.DYN.LE00.IN          7.249390e+01
# SP.POP.GROW             1.285358e+00
# ST.INT.ARVL             8.779477e+06
# ST.INT.DPRT             1.255701e+07
# ST.INT.XPND.MP.ZS       6.172455e+00
# Happy Planet Index      2.635312e+01
# Length: 99, dtype: float64

# %%
# Dealing with NaN values: Impute column mean for NaN values
wdi_hpi_2016_df = wdi_hpi_2016_df.fillna(wdi_hpi_2016_df.mean())

# %%
# Save preprocessed DataFrame
wdi_hpi_2016_df.to_pickle('../data/wdi_hpi_2016_df.pkl')
